# %% [markdown]
# <a href="https://colab.research.google.com/github/MUYang99/Time-Series-Prediction-Based-on-Deep-Learning/blob/main/Multi_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM, TimeDistributed, RepeatVector
from keras.optimizers import adam_v2
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, Callback
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error, r2_score, explained_variance_score
from scipy import stats, arange
from matplotlib.pyplot import MultipleLocator

# %% [markdown]
# # Data Process

# %%
### Import data & dropna
df = pd.read_excel('d2.xlsx')
df = df.dropna()
print(df)
# Out:
#                       Date      NOx  Difftemp  ...   Temp     WD       WS
# 0      2015-01-01 00:15:00  62.2314    -0.070  ...  2.614  278.9  4.81599
# 1      2015-01-01 00:30:00  75.7350    -0.067  ...  2.685  280.9  4.63499
# 2      2015-01-01 00:45:00  70.4414    -0.070  ...  2.778  278.6  3.29300
# 5      2015-01-01 01:30:00  29.6205    -0.071  ...  3.279  292.5  5.41499
# 6      2015-01-01 01:45:00  53.4148    -0.092  ...  3.426  290.0  5.60100
# ...                    ...      ...       ...  ...    ...    ...      ...
# 210426 2020-12-31 22:45:00  11.7719    -0.221  ...  3.674  139.6  2.29500
# 210427 2020-12-31 23:00:00  25.4470    -0.225  ...  3.745  150.5  2.10400
# 210428 2020-12-31 23:15:00  34.3861    -0.212  ...  3.661  151.5  2.87800
# 210429 2020-12-31 23:30:00  47.5379    -0.195  ...  3.562  150.9  2.69900
# 210430 2020-12-31 23:45:00  65.7220    -0.249  ...  3.565  145.1  2.41100
#
# [202485 rows x 10 columns]

# %%
### Data selection(date)
data = df[df.Date < '20151231']
# data = df
data = data.drop(["Date"], axis=1)
nox = data.NOx.values
nox = nox.reshape(len(nox),)

fig = plt.figure(figsize = (10, 6))
ax1 = fig.add_subplot(2, 1, 1)
x  = np.arange(len(nox))
plt.scatter(x, nox, color = 'k', marker = '.', alpha = 0.3)

x_major_locator=MultipleLocator(4*24*30)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlabel('Month')
plt.ylabel('NOx')
plt.grid()

nox.shape
# Out:
# (34063,)

# %%
### Average hour data
d1 = data.values
n = d1.shape[0]%4
m = int((d1.shape[0] - n)/4)
avg = np.zeros((m, d1.shape[1]))
for i in range(d1.shape[1]):
  di = d1[:,i].tolist()
  x = len(di)%4
  while x:
    di.pop()
    x -= 1
  arr = np.array(di).reshape(m, 4)
  temp = np.mean(arr, axis = 1)
  avg[:, i] = temp
avg
# Out:
# array([[ 5.95070750e+01, -6.94999250e-02,  4.99999000e-04, ...,
#          2.83900000e+00,  2.82725000e+02,  4.53974250e+00],
#        [ 3.34482250e+01, -2.40249975e-01,  7.49998500e-04, ...,
#          3.29125000e+00,  2.84875000e+02,  5.60925000e+00],
#        [ 2.81088500e+01, -4.06500000e-01,  0.00000000e+00, ...,
#          2.86075000e+00,  2.82900000e+02,  6.08050000e+00],
#        ...,
#        [ 7.21539000e+01, -8.47499500e-02,  0.00000000e+00, ...,
#          1.80775000e+00,  2.10925000e+02,  4.40874750e+00],
#        [ 7.39727750e+01, -8.67499250e-02,  0.00000000e+00, ...,
#          1.71150000e+00,  2.07150000e+02,  4.02774500e+00],
#        [ 4.95815750e+01, -9.32499750e-02,  0.00000000e+00, ...,
#          1.70575000e+00,  2.07450000e+02,  4.81224750e+00]])

# %%
### NOx hour data
fig = plt.figure(figsize = (10, 6))
ax2 = fig.add_subplot(2, 1, 1)
x  = np.arange(avg.shape[0])
plt.scatter(x, avg[:, 0], color = 'k', marker = '.', alpha = 0.3)

x_major_locator=MultipleLocator(24*30)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlabel('Month')
plt.ylabel('NOx')
plt.grid()

print(avg[:,0].shape)
# Out:
# (8515,)

# %%
### All data
groups = [0,1,2,3,4,5,6,7,8]
i = 1
# plot each column
plt.figure(figsize = (10, 8))
for group in groups:
	plt.subplot(len(groups), 1, i)
	plt.plot(avg[:, group])
	plt.title(df.columns[group+1], y=0.5, loc='right')
	i += 1
plt.show()

# %%
### Data normalization
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(avg)

data.shape
# Out:
# (8515, 9)

# %% [markdown]
# # Build dataset

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

n_lag = 5
n_features = 9
reframed = series_to_supervised(data, n_lag, 1)
reframed.drop(reframed.columns[[46,47,48,49,50,51,52,53]], axis=1, inplace=True)
reframed.head()
# Out:
#    var1(t-5)  var2(t-5)     var3(t-5)  ...  var8(t-1)  var9(t-1)   var1(t)
# 5   0.056084   0.565795  5.140057e-07  ...   0.786132   0.411298  0.013022
# 6   0.030502   0.494351  7.710085e-07  ...   0.774594   0.355603  0.006672
# 7   0.025261   0.424791  0.000000e+00  ...   0.766433   0.403661  0.005112
# 8   0.033897   0.551883  2.570028e-07  ...   0.778252   0.387124  0.005126
# 9   0.008300   0.556904  0.000000e+00  ...   0.757217   0.377038  0.004333
#
# [5 rows x 46 columns]

# %%
values = reframed.values
n_val_hours = 3*24
train = values[:-n_val_hours, :]
test = values[-n_val_hours:,:]

train_X, train_y = train[:-n_lag, :-1], train[:-n_lag, -1]
test_X, test_y = test[:, :-1], test[:, -1]
train_X = train_X.reshape((train_X.shape[0], n_lag, n_features))
test_X = test_X.reshape((test_X.shape[0], n_lag, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8433, 5, 9) (8433,) (72, 5, 9) (72,)

# %% [markdown]
# # LSTM Construction & Training

# %%
### Configure
lr = 1e-4
n_epochs = 300
batchsize = 128
n_neuron = 150

# %%
### Contruct the LSTM
def build_lstm():

  model = Sequential()
  # model.add(LSTM(n_neuron, input_shape=(n_in, n_features)))
  model.add(LSTM(n_neuron, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
  model.add(LSTM(100, return_sequences=False))
  model.add(Dropout(0.2))
  model.add(Dense(1))
  #model.add(Activation("sigmoid"))
  model.compile(optimizer=adam_v2.Adam(learning_rate=lr), loss='mae')

  return model

# %%
### Training LSTM
def model_fit(x_train, y_train, x_val, y_val):
    
    model = build_lstm()

    my_callbacks = [ModelCheckpoint(filepath='my_model.h5', save_best_only=True)]
    # my_callbacks = [EarlyStopping(patience=100), ModelCheckpoint(filepath='my_model.h5', save_best_only=True), ReduceLROnPlateau(factor = 0.1, patience = 50)]
    history = model.fit(x_train, y_train, batch_size=batchsize, epochs=n_epochs, verbose=1, callbacks=my_callbacks, validation_data=(x_val, y_val))
    # history = model.fit(x_train, y_train, batch_size=batchsize, epochs=n_epochs, verbose=1, validation_data=(x_val, y_val))
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='validation')
    plt.legend()
    plt.show()
    
    return model

model = model_fit(train_X, train_y, test_X, test_y)
model = load_model('my_model.h5')
# Out:
# Epoch 1/300
# 66/66 [==============================] - 6s 49ms/step - loss: 0.0518 - val_loss: 0.1116
# Epoch 2/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0447 - val_loss: 0.0973
# Epoch 3/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0412 - val_loss: 0.0848
# Epoch 4/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0384 - val_loss: 0.0769
# Epoch 5/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0370 - val_loss: 0.0746
# Epoch 6/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0362 - val_loss: 0.0732
# Epoch 7/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0360 - val_loss: 0.0723
# Epoch 8/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0357 - val_loss: 0.0718
# Epoch 9/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0352 - val_loss: 0.0715
# Epoch 10/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0347 - val_loss: 0.0710
# Epoch 11/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0343 - val_loss: 0.0696
# Epoch 12/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0340 - val_loss: 0.0694
# Epoch 13/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0336 - val_loss: 0.0680
# Epoch 14/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0331 - val_loss: 0.0671
# Epoch 15/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0328 - val_loss: 0.0670
# Epoch 16/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0323 - val_loss: 0.0663
# Epoch 17/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0317 - val_loss: 0.0646
# Epoch 18/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0311 - val_loss: 0.0626
# Epoch 19/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0305 - val_loss: 0.0616
# Epoch 20/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0300 - val_loss: 0.0595
# Epoch 21/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0295 - val_loss: 0.0580
# Epoch 22/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0291 - val_loss: 0.0579
# Epoch 23/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0287 - val_loss: 0.0569
# Epoch 24/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0285 - val_loss: 0.0559
# Epoch 25/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0283 - val_loss: 0.0558
# Epoch 26/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0279 - val_loss: 0.0551
# Epoch 27/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0277 - val_loss: 0.0539
# Epoch 28/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0276 - val_loss: 0.0545
# Epoch 29/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0274 - val_loss: 0.0545
# Epoch 30/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0271 - val_loss: 0.0521
# Epoch 31/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0268 - val_loss: 0.0538
# Epoch 32/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0268 - val_loss: 0.0525
# Epoch 33/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0266 - val_loss: 0.0510
# Epoch 34/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0263 - val_loss: 0.0513
# Epoch 35/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0261 - val_loss: 0.0508
# Epoch 36/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0260 - val_loss: 0.0493
# Epoch 37/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0259 - val_loss: 0.0496
# Epoch 38/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0258 - val_loss: 0.0487
# Epoch 39/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0255 - val_loss: 0.0485
# Epoch 40/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0256 - val_loss: 0.0488
# Epoch 41/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0258 - val_loss: 0.0491
# Epoch 42/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0257 - val_loss: 0.0487
# Epoch 43/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0252 - val_loss: 0.0479
# Epoch 44/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0254 - val_loss: 0.0469
# Epoch 45/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0252 - val_loss: 0.0463
# Epoch 46/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0250 - val_loss: 0.0467
# Epoch 47/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0250 - val_loss: 0.0467
# Epoch 48/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0251 - val_loss: 0.0467
# Epoch 49/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0251 - val_loss: 0.0462
# Epoch 50/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0250 - val_loss: 0.0459
# Epoch 51/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0251 - val_loss: 0.0459
# Epoch 52/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0251 - val_loss: 0.0459
# Epoch 53/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0251 - val_loss: 0.0458
# Epoch 54/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0249 - val_loss: 0.0453
# Epoch 55/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0250 - val_loss: 0.0452
# Epoch 56/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0249 - val_loss: 0.0454
# Epoch 57/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0250 - val_loss: 0.0455
# Epoch 58/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0250 - val_loss: 0.0450
# Epoch 59/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0249 - val_loss: 0.0452
# Epoch 60/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0250 - val_loss: 0.0462
# Epoch 61/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0249 - val_loss: 0.0463
# Epoch 62/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0247 - val_loss: 0.0460
# Epoch 63/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0248 - val_loss: 0.0456
# Epoch 64/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0248 - val_loss: 0.0459
# Epoch 65/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0247 - val_loss: 0.0454
# Epoch 66/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0248 - val_loss: 0.0463
# Epoch 67/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0247 - val_loss: 0.0455
# Epoch 68/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0247 - val_loss: 0.0453
# Epoch 69/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0248 - val_loss: 0.0453
# Epoch 70/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0246 - val_loss: 0.0449
# Epoch 71/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0247 - val_loss: 0.0454
# Epoch 72/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0247 - val_loss: 0.0456
# Epoch 73/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0246 - val_loss: 0.0446
# Epoch 74/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0246 - val_loss: 0.0454
# Epoch 75/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0246 - val_loss: 0.0455
# Epoch 76/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0246 - val_loss: 0.0455
# Epoch 77/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0245 - val_loss: 0.0451
# Epoch 78/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0245 - val_loss: 0.0464
# Epoch 79/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0247 - val_loss: 0.0452
# Epoch 80/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0244 - val_loss: 0.0450
# Epoch 81/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0244 - val_loss: 0.0448
# Epoch 82/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0244 - val_loss: 0.0447
# Epoch 83/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0244 - val_loss: 0.0457
# Epoch 84/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0243 - val_loss: 0.0450
# Epoch 85/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0242 - val_loss: 0.0454
# Epoch 86/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0244 - val_loss: 0.0449
# Epoch 87/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0243 - val_loss: 0.0450
# Epoch 88/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0244 - val_loss: 0.0451
# Epoch 89/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0245 - val_loss: 0.0450
# Epoch 90/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0243 - val_loss: 0.0451
# Epoch 91/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0242 - val_loss: 0.0448
# Epoch 92/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0242 - val_loss: 0.0459
# Epoch 93/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0245 - val_loss: 0.0458
# Epoch 94/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0242 - val_loss: 0.0454
# Epoch 95/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0242 - val_loss: 0.0446
# Epoch 96/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0245 - val_loss: 0.0458
# Epoch 97/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0242 - val_loss: 0.0446
# Epoch 98/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0242 - val_loss: 0.0454
# Epoch 99/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0243 - val_loss: 0.0459
# Epoch 100/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0242 - val_loss: 0.0451
# Epoch 101/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0242 - val_loss: 0.0461
# Epoch 102/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0241 - val_loss: 0.0454
# Epoch 103/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0241 - val_loss: 0.0453
# Epoch 104/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0240 - val_loss: 0.0460
# Epoch 105/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0240 - val_loss: 0.0455
# Epoch 106/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0240 - val_loss: 0.0460
# Epoch 107/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0241 - val_loss: 0.0453
# Epoch 108/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0241 - val_loss: 0.0458
# Epoch 109/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0242 - val_loss: 0.0456
# Epoch 110/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0240 - val_loss: 0.0454
# Epoch 111/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0240 - val_loss: 0.0455
# Epoch 112/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0240 - val_loss: 0.0458
# Epoch 113/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0239 - val_loss: 0.0454
# Epoch 114/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0239 - val_loss: 0.0459
# Epoch 115/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0240 - val_loss: 0.0460
# Epoch 116/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0239 - val_loss: 0.0463
# Epoch 117/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0239 - val_loss: 0.0454
# Epoch 118/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0240 - val_loss: 0.0465
# Epoch 119/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0239 - val_loss: 0.0463
# Epoch 120/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0239 - val_loss: 0.0461
# Epoch 121/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0238 - val_loss: 0.0465
# Epoch 122/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0239 - val_loss: 0.0459
# Epoch 123/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0238 - val_loss: 0.0461
# Epoch 124/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0241 - val_loss: 0.0457
# Epoch 125/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0464
# Epoch 126/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0239 - val_loss: 0.0459
# Epoch 127/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0468
# Epoch 128/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0239 - val_loss: 0.0467
# Epoch 129/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0238 - val_loss: 0.0470
# Epoch 130/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0239 - val_loss: 0.0465
# Epoch 131/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0461
# Epoch 132/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0239 - val_loss: 0.0465
# Epoch 133/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0466
# Epoch 134/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0238 - val_loss: 0.0467
# Epoch 135/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0464
# Epoch 136/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0238 - val_loss: 0.0465
# Epoch 137/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0471
# Epoch 138/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0469
# Epoch 139/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0239 - val_loss: 0.0467
# Epoch 140/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0237 - val_loss: 0.0476
# Epoch 141/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0238 - val_loss: 0.0472
# Epoch 142/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0237 - val_loss: 0.0475
# Epoch 143/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0239 - val_loss: 0.0467
# Epoch 144/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0238 - val_loss: 0.0467
# Epoch 145/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0476
# Epoch 146/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0237 - val_loss: 0.0468
# Epoch 147/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0479
# Epoch 148/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0237 - val_loss: 0.0473
# Epoch 149/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0235 - val_loss: 0.0468
# Epoch 150/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0238 - val_loss: 0.0468
# Epoch 151/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0237 - val_loss: 0.0467
# Epoch 152/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0477
# Epoch 153/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0469
# Epoch 154/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0471
# Epoch 155/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0238 - val_loss: 0.0473
# Epoch 156/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0236 - val_loss: 0.0468
# Epoch 157/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0478
# Epoch 158/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0470
# Epoch 159/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0237 - val_loss: 0.0473
# Epoch 160/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0467
# Epoch 161/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0481
# Epoch 162/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0472
# Epoch 163/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0469
# Epoch 164/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0469
# Epoch 165/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0477
# Epoch 166/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0469
# Epoch 167/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0464
# Epoch 168/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0467
# Epoch 169/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0475
# Epoch 170/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0236 - val_loss: 0.0471
# Epoch 171/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0475
# Epoch 172/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0468
# Epoch 173/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0476
# Epoch 174/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0238 - val_loss: 0.0469
# Epoch 175/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0475
# Epoch 176/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0472
# Epoch 177/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0474
# Epoch 178/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0464
# Epoch 179/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0471
# Epoch 180/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0472
# Epoch 181/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0472
# Epoch 182/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0478
# Epoch 183/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0236 - val_loss: 0.0467
# Epoch 184/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0237 - val_loss: 0.0470
# Epoch 185/300
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0236 - val_loss: 0.0470
# Epoch 186/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0472
# Epoch 187/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0471
# Epoch 188/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0468
# Epoch 189/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0466
# Epoch 190/300
# 66/66 [==============================] - 3s 44ms/step - loss: 0.0235 - val_loss: 0.0473
# Epoch 191/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0236 - val_loss: 0.0468
# Epoch 192/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0465
# Epoch 193/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0469
# Epoch 194/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0470
# Epoch 195/300
# 66/66 [==============================] - 3s 44ms/step - loss: 0.0235 - val_loss: 0.0471
# Epoch 196/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0472
# Epoch 197/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0236 - val_loss: 0.0472
# Epoch 198/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0467
# Epoch 199/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0470
# Epoch 200/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0466
# Epoch 201/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0467
# Epoch 202/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0466
# Epoch 203/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0237 - val_loss: 0.0470
# Epoch 204/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0473
# Epoch 205/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0470
# Epoch 206/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0237 - val_loss: 0.0466
# Epoch 207/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0469
# Epoch 208/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0463
# Epoch 209/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0235 - val_loss: 0.0467
# Epoch 210/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0469
# Epoch 211/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0464
# Epoch 212/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0471
# Epoch 213/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0462
# Epoch 214/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0235 - val_loss: 0.0462
# Epoch 215/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0236 - val_loss: 0.0463
# Epoch 216/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0461
# Epoch 217/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0465
# Epoch 218/300
# 66/66 [==============================] - 3s 44ms/step - loss: 0.0235 - val_loss: 0.0469
# Epoch 219/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0477
# Epoch 220/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0466
# Epoch 221/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0466
# Epoch 222/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0465
# Epoch 223/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0463
# Epoch 224/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0468
# Epoch 225/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0469
# Epoch 226/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0462
# Epoch 227/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0464
# Epoch 228/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0466
# Epoch 229/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0460
# Epoch 230/300
# 66/66 [==============================] - 3s 44ms/step - loss: 0.0235 - val_loss: 0.0459
# Epoch 231/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0235 - val_loss: 0.0458
# Epoch 232/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0235 - val_loss: 0.0464
# Epoch 233/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0464
# Epoch 234/300
# 66/66 [==============================] - 3s 44ms/step - loss: 0.0234 - val_loss: 0.0463
# Epoch 235/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0465
# Epoch 236/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0482
# Epoch 237/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0465
# Epoch 238/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0235 - val_loss: 0.0467
# Epoch 239/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0235 - val_loss: 0.0466
# Epoch 240/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0465
# Epoch 241/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0236 - val_loss: 0.0473
# Epoch 242/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0470
# Epoch 243/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0236 - val_loss: 0.0463
# Epoch 244/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0461
# Epoch 245/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0459
# Epoch 246/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0235 - val_loss: 0.0467
# Epoch 247/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0466
# Epoch 248/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0464
# Epoch 249/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0464
# Epoch 250/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0465
# Epoch 251/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0235 - val_loss: 0.0462
# Epoch 252/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0236 - val_loss: 0.0467
# Epoch 253/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0465
# Epoch 254/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0461
# Epoch 255/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0465
# Epoch 256/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0463
# Epoch 257/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0464
# Epoch 258/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0464
# Epoch 259/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0234 - val_loss: 0.0457
# Epoch 260/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0460
# Epoch 261/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0460
# Epoch 262/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0457
# Epoch 263/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0466
# Epoch 264/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0233 - val_loss: 0.0458
# Epoch 265/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0459
# Epoch 266/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0235 - val_loss: 0.0463
# Epoch 267/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0235 - val_loss: 0.0458
# Epoch 268/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0462
# Epoch 269/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0235 - val_loss: 0.0455
# Epoch 270/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0236 - val_loss: 0.0454
# Epoch 271/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0461
# Epoch 272/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0462
# Epoch 273/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0458
# Epoch 274/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0463
# Epoch 275/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0459
# Epoch 276/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0234 - val_loss: 0.0460
# Epoch 277/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0234 - val_loss: 0.0457
# Epoch 278/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0461
# Epoch 279/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0459
# Epoch 280/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0457
# Epoch 281/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0457
# Epoch 282/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0460
# Epoch 283/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0454
# Epoch 284/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0456
# Epoch 285/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0233 - val_loss: 0.0462
# Epoch 286/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0459
# Epoch 287/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0461
# Epoch 288/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0233 - val_loss: 0.0453
# Epoch 289/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0233 - val_loss: 0.0460
# Epoch 290/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0233 - val_loss: 0.0464
# Epoch 291/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0461
# Epoch 292/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0457
# Epoch 293/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0463
# Epoch 294/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0461
# Epoch 295/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0233 - val_loss: 0.0464
# Epoch 296/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0233 - val_loss: 0.0458
# Epoch 297/300
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0234 - val_loss: 0.0454
# Epoch 298/300
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0234 - val_loss: 0.0454
# Epoch 299/300
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0234 - val_loss: 0.0460
# Epoch 300/300
# 66/66 [==============================] - 3s 43ms/step - loss: 0.0233 - val_loss: 0.0455

# %% [markdown]
# # Results visualization & Analysis

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_lag*n_features))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, -8:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
Prediction = inv_yhat[:,0]

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, -8:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
Truth = inv_y[:,0]

# %%
### Visualization
x = [x for x in range(n_val_hours)]
fig, ax = plt.subplots(figsize=(15,5), dpi = 300)
ax.plot(x, Prediction, linewidth=2.0, label = "Prediction")
ax.plot(x, Truth, linewidth=2.0, label = "Truth")

x_major_locator=MultipleLocator(24)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

ax.legend(loc=2);
plt.grid(linestyle='-.')
plt.show()

# %%
### Analysis
MSE = mean_squared_error(Truth, Prediction)
RMSE = np.sqrt(MSE)
print('RMSE: %.3f' %RMSE)
MAE = mean_absolute_error(Truth, Prediction)
print('MAE: %.3f' %MAE)
MAPE = np.mean(np.abs((Truth - Prediction) / Truth)) * 100
print('MAPE: %.3f' %MAPE)
MedAE = median_absolute_error(Truth, Prediction)
print('MedAE: %.3f' %MedAE)
r2_score = r2_score(Truth, Prediction)
print('r2_score: %.3f' %r2_score)
explained_variance_score = explained_variance_score(Truth, Prediction)
print('explained_variance_score: %.3f' %explained_variance_score)
# Out:
# RMSE: 82.154
# MAE: 45.409
# MAPE: 37.925
# MedAE: 20.731
# r2_score: 0.712
# explained_variance_score: 0.729
